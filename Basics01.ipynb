# %% [markdown]
# # Introduction to R programming

# %%
x = rnorm(125)
print(x)
# Out:
#   [1] -0.02510203  1.25335138 -0.62119713  0.07164100 -1.55902285  0.61975233
#   [7]  0.98358601 -0.07954106  0.70519179  0.69233410  1.63822937 -0.68728003
#  [13] -0.47633016 -0.51304251  1.08386572  0.69239875  0.37318267 -0.84652473
#  [19]  0.84905992 -0.48626502 -0.88522557 -1.49779302  0.32440624 -1.04170922
#  [25]  0.31825493  1.52654732 -0.12115832  0.05609967 -0.10317688 -0.53690808
#  [31] -0.95061714 -0.56106053 -2.00981627  1.76173014 -1.31207662 -0.18532848
#  [37] -0.94750469  0.67097561 -1.75231894 -0.56585964 -2.38894471 -1.39484349
#  [43] -1.39644759  0.57949276  1.23939997  0.48060976 -0.17135039 -0.10345599
#  [49] -0.08048283  0.78272850 -0.14829325  0.01393018 -0.57978863  0.33164634
#  [55] -1.48053351 -1.09544252 -0.75220334 -1.34327838  1.74424643  0.59102066
#  [61]  1.84162665  0.19236277 -0.94783419  1.10196923 -1.02169251 -1.20220768
#  [67]  1.21345375 -1.60662332 -0.98612982  1.33646922 -0.33802419  0.67283687
# ...

# %% [markdown]
# # Plotting the Normal Graph

# %%
plot(x)
# Out:
# plot without title

# %% [markdown]
# # Plotting the BarPlot

# %%
barplot(x)
# Out:
# plot without title

# %% [markdown]
# # Histogram Plotting

# %%
hist(x)
# Out:
# Plot with title “Histogram of x”

# %% [markdown]
# # Plotting the barplot Graph

# %%
n <- floor(rnorm(10000, 500, 100))
t <- table(n)
barplot(t)
# Out:
# plot without title
